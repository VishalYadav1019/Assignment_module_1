# %%
#import libraries here
import numpy as np 
import pandas as pd
import random

# %%
df=pd.read_csv("C:\\Users\\visha\\OneDrive\\Desktop\\Book6.csv") #load the dataset using read_csv function 
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.isnull().sum()  #check how many null values are in dataset
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            1042
# yearOfRegistration        0
# gearbox                 559
# powerPS                   0
# model                   565
# odometer                  0
# monthOfRegistration       0
# fuelType                929
# brand                     0
# notRepairedDamage      2007
# dateCreated               0
# nrOfPictures              0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
df.isnull().sum().sum()  #find the null value and show the total number of null values
# Out:
# 5102

# %%
df.count #count the total values of rows and columns in the dataset
# Out:
# <bound method DataFrame.count of            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
# ...

# %%
df.isnull() # check the null values
# Out:
#       dateCrawled   name  seller  offerType  price  abtest  vehicleType  \
# 0           False  False   False      False  False   False        False
# 1           False  False   False      False  False   False        False
# 2           False  False   False      False  False   False        False
# 3           False  False   False      False  False   False        False
# 4           False  False   False      False  False   False        False
# ...           ...    ...     ...        ...    ...     ...          ...
# 9995        False  False   False      False  False   False         True
# 9996        False  False   False      False  False   False         True
# 9997        False  False   False      False  False   False        False
# 9998        False  False   False      False  False   False        False
# 9999        False  False   False      False  False   False        False
#
#       yearOfRegistration  gearbox  powerPS  model  odometer  \
# ...

# %%
df.describe() #  find the mean,count,minimum,maximum,standard deviation...
# Out:
#        yearOfRegistration       powerPS  monthOfRegistration  nrOfPictures  \
# count        10000.000000  10000.000000         10000.000000       10000.0
# mean          2006.120100    115.110600             5.775700           0.0
# std            128.663679    119.159048             3.711383           0.0
# min           1910.000000      0.000000             0.000000           0.0
# 25%           1999.000000     71.000000             3.000000           0.0
# 50%           2003.000000    107.000000             6.000000           0.0
# 75%           2008.000000    150.000000             9.000000           0.0
# max           9999.000000   6512.000000            12.000000           0.0
#
#          postalCode
# count  10000.000000
# mean   50338.189400
# std    25627.941684
# min     1067.000000
# 25%    29693.000000
# 50%    49143.000000
# 75%    70771.000000
# max    99994.000000

# %%
df.dropna() #drop the null values columns
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9988  15-03-2016 18:44                           Opel_Astra_1.8_16V_Coupe
# 9989  01-04-2016 12:50                        Volkswagen_Scirocco_1.4_TSI
# 9990  28-03-2016 12:52                                           BMW_116i
# 9993  10-03-2016 17:54                    Renault_Twingo_1.2__Tuev/Au_Neu
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
p=df.head(40) # show the first 40 columns form the dataset.
p
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
p.dropna()
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 12  31-03-2016 19:48  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13  23-03-2016 10:48                                 Audi_A3_1.6_tuning
# 16  16-03-2016 14:59                                Opel_Vectra_B_Kombi
# 17  29-03-2016 11:46                          Volkswagen_Scirocco_2_G60
# 19  17-03-2016 13:36        mazda_tribute_2.0_mit_gas_und_tuev_neu_2018
# ...

# %%
p1=df.fillna(0) # fill the null values as 0 ,and stored in p1 variable

# %%
p1
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
p1.isnull().sum() # again check the null values in p1 variables dataset.
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# odometer               0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
p1.dtypes #check the datatypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                  object
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# odometer               object
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
import pandas as pd
import numpy as np
import random

# %%
df=pd.read_csv("C:\\Users\\visha\\OneDrive\\Desktop\\Book6.csv")
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            1042
# yearOfRegistration        0
# gearbox                 559
# powerPS                   0
# model                   565
# odometer                  0
# monthOfRegistration       0
# fuelType                929
# brand                     0
# notRepairedDamage      2007
# dateCreated               0
# nrOfPictures              0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
p=df.fillna(0)

# %%
df.dropna()
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9988  15-03-2016 18:44                           Opel_Astra_1.8_16V_Coupe
# 9989  01-04-2016 12:50                        Volkswagen_Scirocco_1.4_TSI
# 9990  28-03-2016 12:52                                           BMW_116i
# 9993  10-03-2016 17:54                    Renault_Twingo_1.2__Tuev/Au_Neu
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType    price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.isnull().sum()
# Out:
# dateCrawled               0
# name                      0
# seller                    0
# offerType                 0
# price                     0
# abtest                    0
# vehicleType            1042
# yearOfRegistration        0
# gearbox                 559
# powerPS                   0
# model                   565
# odometer                  0
# monthOfRegistration       0
# fuelType                929
# brand                     0
# notRepairedDamage      2007
# dateCreated               0
# nrOfPictures              0
# postalCode                0
# lastSeen                  0
# dtype: int64

# %%
p.isnull().sum()
# Out:
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# odometer               0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
p.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                  object
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# odometer               object
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
p.select_dtypes(include= "int64") # show the values whoes dataypes is int64..
# Out:
#       yearOfRegistration  powerPS  monthOfRegistration  nrOfPictures  \
# 0                   2004      158                    3             0
# 1                   1997      286                    6             0
# 2                   2009      102                    7             0
# 3                   2007       71                    6             0
# 4                   2003        0                    7             0
# ...                  ...      ...                  ...           ...
# 9995                2005      163                    3             0
# 9996                2017      105                    0             0
# 9997                1999       75                   11             0
# 9998                2001        0                    2             0
# 9999                2002      102                   10             0
#
#       postalCode
# 0          79588
# 1          71034
# 2          35394
# 3          33729
# 4          39218
# ...          ...
# ...

# %%
p1=p.head(40)
p1
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
p1.select_dtypes(exclude= "int64") # show the columns exclude int64..
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
p1.select_dtypes(include = "object") # show the columns only including object
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df.to_excel("auto29.xlsx") # convert the csv file into excel..

# %%
ran=np.random.randint(30, size=len(df)) # using random libraries show the randomly 30 values from the dataset
ran
# Out:
# array([11, 20,  2, ..., 15, 12,  2])

# %%
p1
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
h = p1.head(15)
h
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
ran=np.random.randint(30, size=len(p1))
ran
# Out:
# array([ 1, 26,  3, 25, 21, 20, 27, 27, 22, 13, 27, 11,  4,  8,  9,  8, 19,
#         7, 19, 13, 23, 14, 11, 18, 11,  1, 20, 13,  3, 12,  9, 12,  5, 11,
#         6,  5, 26,  6, 16, 23])

# %%
import numpy as np 
import pandas as pd
import random

# %%
df=pd.read_csv("C:\\Users\\visha\\OneDrive\\Desktop\\Book6.csv") 
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
p1=df.head(40)

# %%
p1
# Out:
#          dateCrawled                                               name  \
# 0   26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4   01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5   21-03-2016 13:47  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7   16-03-2016 18:55                               Golf_IV_1.9_TDI_90PS
# 8   22-03-2016 16:51                                         Seat_Arosa
# 9   16-03-2016 13:47          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10  15-03-2016 01:41                       VW_Golf_Tuning_in_siber/grau
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# ...

# %%
p1.sample(frac = 0.25) # here get 25% data from the dataset..
# Out:
#          dateCrawled                                               name  \
# 2   26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 27  27-03-2016 18:45             Hat_einer_Ahnung_mit_Ford_Galaxy_HILFE
# 16  16-03-2016 14:59                                Opel_Vectra_B_Kombi
# 6   20-03-2016 17:55  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 17  29-03-2016 11:46                          Volkswagen_Scirocco_2_G60
# 3   12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 31  14-03-2016 16:53                          Noch_gut_erhaltenen_C_320
# 26  03-04-2016 22:46                                Volkswagen_Polo_Fox
# 11  16-03-2016 18:45                         Mercedes_A140_Motorschaden
# 1   04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
#
#     seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 2   privat   Angebot  $8,990     test   limousine                2009
# ...

# %%
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
p1["powerPS"].where(p1["powerPS"]>50) #show the coloumn of powerps whose  value is greater then 50..
# Out:
# 0     158.0
# 1     286.0
# 2     102.0
# 3      71.0
# 4       NaN
# 5     150.0
# 6      90.0
# 7      90.0
# 8       NaN
# 9      90.0
# 10     90.0
# 11      NaN
# 12     71.0
# 13    101.0
# 14     75.0
# 15    203.0
# 16    101.0
# 17    205.0
# 18    150.0
# 19    124.0
# 20    131.0
# 21    320.0
# 22    184.0
# 23    120.0
# 24    306.0
# 25    116.0
# 26     54.0
# 27      NaN
# 28    110.0
# 29    204.0
# 30     60.0
# 31    218.0
# 32      NaN
# 33    140.0
# 34    193.0
# 35      NaN
# 36    131.0
# 37    140.0
# 38     75.0
# 39    122.0
# Name: powerPS, dtype: float64

# %%
p1["powerPS"].where(p1["powerPS"] > 50 ,0) #where location 0 means replace the null with 0.
# Out:
# 0     158
# 1     286
# 2     102
# 3      71
# 4       0
# 5     150
# 6      90
# 7      90
# 8       0
# 9      90
# 10     90
# 11      0
# 12     71
# 13    101
# 14     75
# 15    203
# 16    101
# 17    205
# 18    150
# 19    124
# 20    131
# 21    320
# 22    184
# 23    120
# 24    306
# 25    116
# 26     54
# 27      0
# 28    110
# 29    204
# 30     60
# 31    218
# 32      0
# 33    140
# 34    193
# 35      0
# 36    131
# 37    140
# 38     75
# 39    122
# Name: powerPS, dtype: int64

# %%
p1.brand.unique()   #unique values from the brand columns...
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini'], dtype=object)

# %%
import numpy as np
import pandas as pd
import random

# %%
df=pd.read_csv("C:\\Users\\visha\\OneDrive\\Desktop\\Book6.csv")
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df["odometer"].max() # max show the maximum value in the column
# Out:
# '90,000km'

# %%
df.dtypes
# Out:
# dateCrawled            object
# name                   object
# seller                 object
# offerType              object
# price                  object
# abtest                 object
# vehicleType            object
# yearOfRegistration      int64
# gearbox                object
# powerPS                 int64
# model                  object
# odometer               object
# monthOfRegistration     int64
# fuelType               object
# brand                  object
# notRepairedDamage      object
# dateCreated            object
# nrOfPictures            int64
# postalCode              int64
# lastSeen               object
# dtype: object

# %%
df["powerPS"].max()
# Out:
# 6512

# %%
df
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
df["powerPS"].median() # median is used to find the average of the columns...
# Out:
# 107.0

# %%
df["powerPS"].sum() # sum of the columns
# Out:
# 1151106

# %%
da=df.rename(columns = {"monthOfRegistration":"Registration Month"})
da # rename the columns as per requerement
# Out:
#            dateCrawled                                               name  \
# 0     26-03-2016 17:47                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1     04-04-2016 13:38         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2     26-03-2016 18:57                         Volkswagen_Golf_1.6_United
# 3     12-03-2016 16:58  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4     01-04-2016 14:38  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# ...                ...                                                ...
# 9995  11-03-2016 20:55              Skoda_Superb_2_5TDI_zahnriemen_neu!!!
# 9996  05-03-2016 20:57             Verkaufe_mein_Golf_4_mit_Sport_Edition
# 9997  31-03-2016 20:56             Ford_Focus_Mk1_Bastler_Fahrzeug/Export
# 9998  23-03-2016 22:51              Smart_Fortwo_Automatik_Klima_Alufegen
# 9999  10-03-2016 02:36                                Volkswagen_T4_Kombi
#
#       seller offerType   price   abtest vehicleType  yearOfRegistration  \
# ...

# %%
da["fuelType"].value_counts()
# Out:
# fuelType
# benzin     5942
# diesel     2968
# lpg         127
# cng          24
# hybrid        5
# elektro       3
# andere        2
# Name: count, dtype: int64
